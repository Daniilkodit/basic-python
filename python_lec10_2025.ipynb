# %% [markdown]
# # Лекция 10. Библиотека Pandas

# %% [markdown]
# ## Подключение библиотеки

# %% [markdown]
# [Pandas](https://pandas.pydata.org/) — это популярная библиотека для языка программирования Python, содержащая инструменты **для эффективной работы с табличной информацией**.
#
# Pandas предоставляет множество встроенных функций для загрузки данных из различных форматов (CSV, Excel, JSON и др.), их дальнейшего анализа и обработки.
# С Pandas удобно проводить статистические вычисления, объединять таблицы, обрабатывать пропущенные значения и визуализировать результаты.
#
# Подробную информацию о возможностях Pandas можно найти в [официальной документации](https://pandas.pydata.org/docs/).
#
# Устанавливается библиотека при помощи команды `pip install pandas` в командной строке или с восклицательным знаком в ячейке Jupyter:

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/tkhirianov/miniconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /home/tkhirianov/miniconda3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/tkhirianov/miniconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/tkhirianov/miniconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/tkhirianov/miniconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/tkhirianov/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# При подключении библиотеки Pandas "под капотом" автоматически подключается библиотека NumPy, но мы подключим их обе явным образом:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Объекты класса `Series`

# %% [markdown]
# Основными структурами данных в Pandas являются `Series` (серия) и `DataFrame` (лист с данными).
#
# `Series` — динамически расширяемый **одномерный массив с метками**.

# %% [markdown]
# ### Создание серий

# %% [markdown]
# Серия создаётся через функцию `pd.Series`.

# %%
ages = pd.Series([22, 35, 25, 16])

# %% [markdown]
# **Метки** (label-based indexing) дают доступ к элементам серии:

# %%
ages[0]
# Out:
# 22

# %% [markdown]
# При распечатке серии мы видим не только значения, но и их метки.
# Если индексы-метки не указать при создании серии, то по умолчанию они совпадают с порядковыми индексами от 0.

# %%
print(ages)
# Out:
# 0    22
# 1    35
# 2    25
# 3    16
# dtype: int64

# %% [markdown]
# У серии может быть имя, которое указывают при её создании в параметре `name`:

# %%
ages = pd.Series([22, 35, 25, 16], name="age")
print(ages)
# Out:
# 0    22
# 1    35
# 2    25
# 3    16
# Name: age, dtype: int64

# %% [markdown]
# Как и у массивов NumPy, можно явно указать тип элементов. Типы элементов совпадают с типами `dtype` библиотеки NumPy.

# %%
ages = pd.Series([22, 35, 25, 16], dtype=np.int32, name="age")
print(ages)
# Out:
# 0    22
# 1    35
# 2    25
# 3    16
# Name: age, dtype: int32

# %% [markdown]
# Можно *явно* указать индексы через параметр `index` конструктора `Series`:

# %%
named_ages = pd.Series(data=[22, 35, 25, 16],
                       index=["Aline", "Beatrice", "Clara", "Diana"],
                       dtype=np.int32, name="age")
print(named_ages)
# Out:
# Aline       22
# Beatrice    35
# Clara       25
# Diana       16
# Name: age, dtype: int32

# %% [markdown]
# Доступ с квадратными скобками `series[i]` ищет значение по его метке, даже если метка — строка:

# %%
named_ages["Beatrice"]
# Out:
# 35

# %% [markdown]
# Это чем-то напоминает словарь `dict`, однако ячейки в серии **упорядочены** и при необходимости к ним можно получать доступ и по **порядковым индексам**.

# %% [markdown]
# ### Локаторы `loc` и `iloc`

# %% [markdown]
# **Метки** (label-based indexing) нужно хорошо отличать от **порядковых индексов**!
#
# Создадим простую серию с числами от 0 до 900:

# %%
numbers = pd.Series(range(0, 1000, 100))
print(numbers)
# Out:
# 0      0
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# 6    600
# 7    700
# 8    800
# 9    900
# dtype: int64

# %% [markdown]
# Можно видеть, что по умолчанию метки начались с 0 и следуют до 9.
#
# Возьмём срез серии:

# %%
the_slice = numbers[2:7]
print(the_slice)
# Out:
# 2    200
# 3    300
# 4    400
# 5    500
# 6    600
# dtype: int64

# %% [markdown]
# Обратите внимание! После среза серии **индексы-метки остались закреплёнными за своими значениями элементов**.
#
# Это правильно с точки зрения *идентификации* хранимых данных. Например, если данные про одну сущность будут находиться в разных сериях и потом их нужно будет сопоставлять.
#
# Убедимся, что доступ с квадратными скобками означает **поиск по метке**:

# %%
the_slice[2]
# Out:
# 200

# %% [markdown]
# Если же для такой неоднозначной ситуации взять срез, то мы получим срез по порядковым индексам:

# %%
the_slice[2:5]
# Out:
# 4    400
# 5    500
# 6    600
# dtype: int64

# %% [markdown]
# Как видите, мы получили срез по порядковым индексам. Получается, что при доступе с квадратными скобами мы имеем **неодозначность индексации**.
#
# Достоверно получить доступ к элементам серии по порядковому индексу можно через **локатор** `iloc`:

# %%
the_slice.iloc[2:5]
# Out:
# 4    400
# 5    500
# 6    600
# dtype: int64

# %% [markdown]
# А достоверный доступ и срез через индексы-метки мы получим через **локатор** `loc`:

# %%
the_slice.loc[2:5]
# Out:
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %% [markdown]
# Взгляните! Элемент с индексом-меткой 5 включён в срез, что противоречит логике `range(start, stop, step)`.
#
# Почему так?! Подумайте про срезы с метками строкового типа и посмотрите на пример ниже:

# %%
named_ages.loc["Beatrice":"Diana"]
# Out:
# Beatrice    35
# Clara       25
# Diana       16
# Name: age, dtype: int32

# %% [markdown]
# ### Изменение, удаление и добавление элементов в `Series`

# %% [markdown]
# Серии являются **изменяемыми**.
#
# При присваивании в существующую метку у неё меняется значение:

# %%
s = pd.Series(data=[0, 10, 20, 30], index=[1, 2, 3, 4])
print(s)
s.loc[4] = 80
print(s)
# Out:
# 1     0
# 2    10
# 3    20
# 4    30
# dtype: int64
# 1     0
# 2    10
# 3    20
# 4    80
# dtype: int64

# %% [markdown]
# Можно **присваивать в срез**:

# %%
s.loc[1:3] = range(5, 30, 10)
print(s)
# Out:
# 1     5
# 2    15
# 3    25
# 4    80
# dtype: int64

# %% [markdown]
# В отличие от массивов NumPy, серии имеют **переменный размер**.
#
# Это означает, что возможно **удаление элемента**:

# %%
del s[3]  # удаление элемента с индексом-меткой 3
print(s)
# Out:
# 1     5
# 2    15
# 4    80
# dtype: int64

# %% [markdown]
# Можно удалить и вернуть значение одновременно методом `pop`:

# %%
x = s.pop(1)  # удаление элемента с индексом-меткой 1
print(x)
# Out:
# 5

# %%
print(s)
# Out:
# 2    15
# 4    80
# dtype: int64

# %% [markdown]
# **Элемент серии — это пара (метка, значение)**, поэтому нельзя просто положить в серию значение: ему *нужен* индекс-метка.
#
# Поэтому **добавление элемента** делают через присваивание в локатор `loc` с указанием *новой* метки:

# %%
s.loc[1] = 100
print(s)
# Out:
# 2     15
# 4     80
# 1    100
# dtype: int64

# %% [markdown]
# Обратите внимание, что таким добавлением **можно нарушить порядок индексов**.

# %%
s.loc[5] = 30
s.loc[3] = 40
s
# Out:
# 2     15
# 4     80
# 1    100
# 5     30
# 3     40
# dtype: int64

# %% [markdown]
# Посмотрим на индекс серии через её атрибут `index`:

# %%
s.index
# Out:
# Index([2, 4, 1, 5, 3], dtype='int64')

# %% [markdown]
# Посмотрим, как будут работать срезы в данном случае:

# %%
s.loc[1:3]
# Out:
# 1    100
# 5     30
# 3     40
# dtype: int64

# %%
s.loc[1:2]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Вероятно, такой ситуации лучше не создавать. Проверить,  упорядочен ли индекс по возрастанию или нет можно при помощи флажка `is_monotonic_increasing` у атрибута `index`:

# %%
s.index.is_monotonic_increasing
# Out:
# False

# %% [markdown]
# Т.к. они упорядочены и изменяемы, **серии можно сортировать**.
#
# Если нужно упорядочить серию по индексам-меткам, это делают при помощи `sort_index`:

# %%
s.sort_index(inplace=True)
print(s)
# Out:
# 1    100
# 2     15
# 3     40
# 4     80
# 5     30
# dtype: int64

# %% [markdown]
# Если сортировка должна идти *по значениям*, это делают при помощи `sort_values`:

# %%
s.sort_values(inplace=True)
print(s)
# Out:
# 2     15
# 5     30
# 3     40
# 4     80
# 1    100
# dtype: int64

# %% [markdown]
# ### Конкатенация серий

# %% [markdown]
# Конкатенация серий происходит при помощи функции `pd.concat`:

# %%
a = pd.Series(data=[10, 20, 40], index=[1, 2, 4])
b = pd.Series(data=[100, 200, 300], index=[1, 2, 3])
c = pd.concat([a, b])
print(c)
# Out:
# 1     10
# 2     20
# 4     40
# 1    100
# 2    200
# 3    300
# dtype: int64

# %% [markdown]
# Мы видим курьёзную ситуацию с индексами-метками. Посмотрим на атрибут серии `index`:

# %%
c.index
# Out:
# Index([1, 2, 4, 1, 2, 3], dtype='int64')

# %% [markdown]
# После конкатенации **индексы-метки могут оказаться не уникальными**!

# %%
c[1] = 10000
print(c)
# Out:
# 1    10000
# 2       20
# 4       40
# 1    10000
# 2      200
# 3      300
# dtype: int64

# %% [markdown]
# Присваивание в такую метку приводит *к изменению всех значений с этой меткой*.
#
# Лучше такой ситуации не создавать. Так можно проверить, что метки уникальны:

# %%
c.index.is_unique
# Out:
# False

# %% [markdown]
# Если нужно провести **переиндексацию**, можно воспользоваться методом `reset_index`:

# %%
c.reset_index(inplace=True, drop=True)

# %%
c
# Out:
# 0    10000
# 1       20
# 2       40
# 3    10000
# 4      200
# 5      300
# dtype: int64

# %% [markdown]
# ### Редукция серий
# В сериях допускаются **отсутствующие значения**, которые представлены как `NaN` (Not a Number).
#
# Соответственно, и агрегирующие методы по сравнению с массивами `NumPy.ndarray` в сериях переопределены: пустые ячейки просто *игнорируются*.

# %%
values = [1, 3, 5, np.nan, 1, np.nan, 3]
array = np.array(values)
series = pd.Series(values)

for container in array, series:
    print(type(container))
    print(container.min(),
          container.max(),
          container.sum(),
          container.prod(), sep='\t')
# Out:
# <class 'numpy.ndarray'>
# nan	nan	nan	nan
# <class 'pandas.core.series.Series'>
# 1.0	5.0	13.0	45.0

# %% [markdown]
# Множество уникальных значений из серии можно получить методом `unique()`.
#
# Поскольку для массива уникальных значений теряется смысл индексов-меток, результат этой операции — это  не `Series`, а массив NumPy `ndarray`:

# %%
series.unique()
# Out:
# array([ 1.,  3.,  5., nan])

# %% [markdown]
# Частотный анализ для значений в серии можно запустить методом `value_counts`:

# %%
series.value_counts()
# Out:
# 1.0    2
# 3.0    2
# 5.0    1
# Name: count, dtype: int64

# %% [markdown]
# Кроме `min`, `max`, `sum`, `prod`, для редукции значений серии есть также методы:

# %%
series.mean()  # среднее арифметическое
# Out:
# 2.6

# %%
series.std()  # среднеквадратическое отклонение
# Out:
# 1.6733200530681511

# %%
series.median()  # медиана
# Out:
# 3.0

# %%
series.quantile(3/4)  # произвольный квантиль, например, 3-я квартиль (число, меньше либо равно которого 75% чисел серии)
# Out:
# 3.0

# %% [markdown]
# Все функции выше вычислялись только *для содержательных, непустых* элементов серии.
#
# Узнать их количество можно методом `count`:

# %%
series.count()  # количество содержательных элементов в серии
# Out:
# 5

# %% [markdown]
# ### Отсутствующие значения в серии

# %% [markdown]
# Поскольку в серии допускаются значения `NaN`, которые по умолчанию не учитываются в статистических функциях, нужно уметь с ними работать:
# 1. проверять факт их наличия в серии,
# 2. считать их количество,
# 3. выбрасывать (`drop`) такие ячейки из серии,
# 4. массово заменять их на другие значения.

# %%
series.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# dtype: bool

# %% [markdown]
# Эту логическую серию можно редуцировать при помощи метода `any`, чтобы узнать **факт наличия NaN в серии**:

# %%
series.isna().any()
# Out:
# True

# %% [markdown]
# Просуммировав эту серию, мы узнаем **количество пустых ячеек**, т.к. при арифметическом сложении превращаются `True` — в `1`, а `False` — в `0`:

# %%
series.isna().sum()
# Out:
# 2

# %% [markdown]
# При помощи `dropna` можно **выбросить NaN из серии**:

# %%
series.dropna()
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 4    1.0
# 6    3.0
# dtype: float64

# %% [markdown]
# Надо помнить, что метод `dropna`, как и многие другие методы, *не модифицирует текущую серию, а создаёт и возвращает новую*. Поэтому наша серия останется в старом состоянии:

# %%
series
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    1.0
# 5    NaN
# 6    3.0
# dtype: float64

# %% [markdown]
# Если мы хотим не создать новую, но **поменять текущую серию**, нужно указать значение ключевого параметра `inplace` как `True`:

# %%
series.dropna(inplace=True)
series
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 4    1.0
# 6    3.0
# dtype: float64

# %% [markdown]
# То же касается метода `fillna` **для массовой замены** `NaN` на другое значение:

# %%
series = pd.Series([1, 3, 5, np.nan, 1, np.nan, 3])
series.fillna(0, inplace=True)
series
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    0.0
# 4    1.0
# 5    0.0
# 6    3.0
# dtype: float64

# %% [markdown]
# ### Векторные (массовые операции)

# %% [markdown]
# Как и для массивов NumPy, для серий работают массовые операции:

# %%
A = pd.Series(data=[10, 20, 30, 40], index=["A", "B", "C", "D"])
B = pd.Series(data=[1, 2, 3, 4], index=["A", "B", "C", "D"])

# %%
A + B
# Out:
# A    11
# B    22
# C    33
# D    44
# dtype: int64

# %%
A * B
# Out:
# A     10
# B     40
# C     90
# D    160
# dtype: int64

# %% [markdown]
# Массовые операции работают не только с двумя сериями, но и с константами:

# %%
-A + 25
# Out:
# A    15
# B     5
# C    -5
# D   -15
# dtype: int64

# %%
A > 20
# Out:
# A    False
# B    False
# C     True
# D     True
# dtype: bool

# %%
B == 3
# Out:
# A    False
# B    False
# C     True
# D    False
# dtype: bool

# %%
B != 3
# Out:
# A     True
# B     True
# C    False
# D     True
# dtype: bool

# %% [markdown]
# Применить какую-то функцию к каждому элементу серии можно при помощи метода `apply`:

# %%
B.apply(lambda x: x*100)
# Out:
# A    100
# B    200
# C    300
# D    400
# dtype: int64

# %% [markdown]
# Все вышеперечисленные операции *создают новую серию*, а старая остаётся неизменной.

# %% [markdown]
# Для серий **массовые операции работают иначе**, чем для массивов NumPy:
# векторные операции происходят **с учётом индексов-меток**.

# %%
A = pd.Series(data=[10, 20, 30, 40], index=["A", "B", "C", "D"])
B = pd.Series(data=[1, 2, 3, 4], index=["B", "C", "D", "A"])

# %%
B + A
# Out:
# A    14
# B    21
# C    32
# D    43
# dtype: int64

# %% [markdown]
# Значения из одной серии можно *массово скопировать в другую серию* методом `update`, при этом опора будет производиться **на индексы-метки**, а не на последовательность элементов. При этом для меток старой серии, к которой не найдены метки новой серии, будут оставлены старые значения:

# %%
A = pd.Series(data=[100, 200, 500, 0],
              index=["Aline", "Beatrice", "Clara", "Diana"], name="money")
B = pd.Series(data=[300, 0], index=["Diana", "Aline"])
print(A)
A.update(B)
print(A)
# Out:
# Aline       100
# Beatrice    200
# Clara       500
# Diana         0
# Name: money, dtype: int64
# Aline         0
# Beatrice    200
# Clara       500
# Diana       300
# Name: money, dtype: int64

# %% [markdown]
# ## Объекты класса `DataFrame`

# %% [markdown]
# После знакомства с сериями `Series` легче понять, как формируется лист с данными.
#
# По сути, это несколько серий-столбцов с одинаковым индексом по вертикали, а последовательность имён столбцов составляет горизонтальный индекс таблицы.

# %%
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6], "C": [7, 8, 9]},
                  index = ["first", "second", "third"])
df
# Out:
#         A  B  C
# first   1  4  7
# second  2  5  8
# third   3  6  9

# %%
df.index
# Out:
# Index(['first', 'second', 'third'], dtype='object')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %% [markdown]
# Доступ к сериям-столбцам можно делать через квадратные скобки или через оператор `.` (если имя является допустимым идентификатором):

# %%
df['A']
# Out:
# first     1
# second    2
# third     3
# Name: A, dtype: int64

# %%
df.A
# Out:
# first     1
# second    2
# third     3
# Name: A, dtype: int64

# %% [markdown]
# Убедимся, что это просто серия:

# %%
type(df.A)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Однако, отличие в доступе всё-таки есть. Через точку нельзя создать новый столбец:

# %%
df.D = df.A*100 + df.B*10 + df.C
df
# Out:
# /tmp/ipykernel_72309/4145806869.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.D = df.A*100 + df.B*10 + df.C
#         A  B  C
# first   1  4  7
# second  2  5  8
# third   3  6  9

# %% [markdown]
# А через квадратные скобки — можно:

# %%
df['D'] = df.A*100 + df.B*10 + df.C
df
# Out:
#         A  B  C    D
# first   1  4  7  147
# second  2  5  8  258
# third   3  6  9  369

# %%
df['D']
# Out:
# first     147
# second    258
# third     369
# Name: D, dtype: int64

# %% [markdown]
# ### Сложности индексации и их решение: loc, iloc.

# %% [markdown]
# Квадратные скобки дают доступ как к столбцам, так и в случае среза к строкам:

# %%
df[1:3]  # срез по порядковым индексам
# Out:
#         A  B  C    D
# second  2  5  8  258
# third   3  6  9  369

# %%
df['first':'second']  # срез по индексам-меткам (включая конечную)
# Out:
#         A  B  C    D
# first   1  4  7  147
# second  2  5  8  258

# %% [markdown]
# Как вы помните, это может приводить к неоднозначности, поэтому при доступе к строкам **лучше всегда использовать `loc`** или `iloc`:

# %%
df.iloc[1:3]
# Out:
#         A  B  C    D
# second  2  5  8  258
# third   3  6  9  369

# %%
df.loc['first':'second']
# Out:
#         A  B  C    D
# first   1  4  7  147
# second  2  5  8  258

# %% [markdown]
# Новая возможность: локатор позволяет получить *серию значений одной строки*. В этом случае индекс строки становится `name` серии:

# %%
df.loc['second']
# Out:
# A      2
# B      5
# C      8
# D    258
# Name: second, dtype: int64

# %% [markdown]
# *Запятая в квадратных скобках* позволяет достать **значение конкретной ячейки** или **срез по строкам и столбцам одновременно**:

# %%
df.loc['first', 'A']
# Out:
# 1

# %%
df.loc['first':'second', 'B':'C']
# Out:
#         B  C
# first   4  7
# second  5  8

# %% [markdown]
# **Локатор может принимать список индексов**, причём в произвольном порядке:

# %%
df.loc[['third', 'first'], ['D', 'B', 'C']]
# Out:
#          D  B  C
# third  369  6  9
# first  147  4  7

# %% [markdown]
# В срезах можно пропускать параметры начала и конца, а также указывать третий параметр — шаг:

# %%
df.iloc[:, ::-1]
# Out:
#           D  C  B  A
# first   147  7  4  1
# second  258  8  5  2
# third   369  9  6  3

# %% [markdown]
# ### Редукция столбцов и строк

# %% [markdown]
# Очевидно, редукцию одного конкретного столбца или строки с конкретным индексом можно выполнить, предварительно выделив её как `Series`, но есть и возможность массовой редукции **по заданной оси**:

# %%
df.sum(axis=1)  # указываем axis=1 для свёртки по горизонтали
# Out:
# first     159
# second    273
# third     387
# dtype: int64

# %%
df.sum()  # по-умолчанию axis=0, свёртка по вертикали
# Out:
# A      6
# B     15
# C     24
# D    774
# dtype: int64

# %% [markdown]
# Также найдём максимальные значения по умолчанию (по вертикали), а затем по горизонтали:

# %%
df.max()
# Out:
# A      3
# B      6
# C      9
# D    369
# dtype: int64

# %%
df.max(axis=1)
# Out:
# first     147
# second    258
# third     369
# dtype: int64

# %% [markdown]
# Для поиска местоположения минимума и максимума есть функции `idxmin` и `idxmax`:

# %%
df.idxmax(axis=1)
# Out:
# first     D
# second    D
# third     D
# dtype: object

# %% [markdown]
# **Cвёртку сразу несколькими функциями** можно сделать при помощи метода `aggregate` (синоним `agg`):

# %%
df.aggregate(['min', 'idxmin', 'max', 'idxmax', 'mean', 'sum'])
# Out:
#             A      B      C      D
# min         1      4      7    147
# idxmin  first  first  first  first
# max         3      6      9    369
# idxmax  third  third  third  third
# mean      2.0    5.0    8.0  258.0
# sum         6     15     24    774

# %% [markdown]
# ### Чистка данных. Методы `drop` и `dropna`

# %% [markdown]
# Исходные данные часто содержат лишнюю информацию, которую требуется исключить.
#
# Если нужно сохранить изменения в самой таблице, то следует добавлять параметр `inplace=True`, но сейчас мы этого делать не будем, оставляя лист в его исходном состоянии.
#
# Чтобы **отбросить лишние столбцы**, используют метод `drop` с ключевым параметром `columns` и списком имён:

# %%
df2 = df.drop(columns=['B', 'D'])
df2
# Out:
#         A  C
# first   1  7
# second  2  8
# third   3  9

# %% [markdown]
# Для отбрасывания строк используют метод `drop` с ключевым параметром `labels`:

# %%
df.drop(labels=['first'])
# Out:
#         A  B  C    D
# second  2  5  8  258
# third   3  6  9  369

# %% [markdown]
# Теперь добавим в лист одну ячейку `NaN`:

# %%
df.loc['second', 'C'] = np.nan
df
# Out:
#         A  B    C    D
# first   1  4  7.0  147
# second  2  5  NaN  258
# third   3  6  9.0  369

# %% [markdown]
# Теперь посмотрите, как работает метод `dropna`:

# %%
df.dropna()  # по умолчанию выбрасываются все строки, в которых есть хотя бы одно значение NaN
# Out:
#        A  B    C    D
# first  1  4  7.0  147
# third  3  6  9.0  369

# %%
df.dropna(axis='columns')  # можно вместо строк с NaN выбросить столбцы:
# Out:
#         A  B    D
# first   1  4  147
# second  2  5  258
# third   3  6  369

# %% [markdown]
# Кроме стратегии выбрасывания данных есть ещё возможность заполнить пропуски константой:

# %%
df.fillna(0)
# Out:
#         A  B    C    D
# first   1  4  7.0  147
# second  2  5  0.0  258
# third   3  6  9.0  369

# %% [markdown]
# Или, как вариант, заполнить ячейки `NaN` через **интерполяцию** <sup>[[1]](https://ru.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D1%80%D0%BF%D0%BE%D0%BB%D1%8F%D1%86%D0%B8%D1%8F)</sup> по соседним ячейкам серии-столбца:

# %%
df.interpolate()
# Out:
#         A  B    C    D
# first   1  4  7.0  147
# second  2  5  8.0  258
# third   3  6  9.0  369

# %% [markdown]
# ## Сложные приёмы обработки данных

# %% [markdown]
# Есть некоторые приёмы работы с `DataFrame`, которые позволяют быстро переформатировать данные так, чтобы необходимая информация лежала на поверхности.
#
# Документацию по API Reference можно [скачать на офиц.сайте](https://pandas.pydata.org/docs/reference/frame.html) Pandas.
#
# Представьте себе ситуацию, когда исходная таблица с данными содержит случаи, которые можно *классифицировать* по нескольким категориям. Например, друзья работали на огороде и собирали картошку и морковку. Вот таблица их "вкладов" в общую корзину:

# %%
commits = pd.DataFrame({"name": ["Петя", "Вася", "Таня", "Петя", "Петя", "Таня", "Вася", "Петя", "Таня"],
                        "potatoes": [3, 4, 0, 3, 4, 0, 6, 3, 0],
                        "carrots": [0, 2, 5, 2, 1, 4, 15, 2, 6]})
commits
# Out:
#    name  potatoes  carrots
# 0  Петя         3        0
# 1  Вася         4        2
# 2  Таня         0        5
# 3  Петя         3        2
# 4  Петя         4        1
# 5  Таня         0        4
# 6  Вася         6       15
# 7  Петя         3        2
# 8  Таня         0        6

# %% [markdown]
# Конечно, мы можем найти суммарное количество картошек и морковок в общей корзине или минимальное/максимальное количество за 1 вклад:

# %%
commits.sum()
# Out:
# name        ПетяВасяТаняПетяПетяТаняВасяПетяТаня
# potatoes                                      23
# carrots                                       37
# dtype: object

# %%
commits.agg(["min", "max"])
# Out:
#      name  potatoes  carrots
# min  Вася         0        0
# max  Таня         6       15

# %% [markdown]
# Однако имена тут только мешают, не имеют содержательной информации. А хотелось бы узнать статистику по каждому другу отдельно...

# %% [markdown]
# ### Метод `groupby`

# %% [markdown]
# Метод `groupby` осуществляет что-то вроде корзинной сортировки для последующей редукции.
#
# Группировка происходит по уникальным значениям в указанном столбце. Эти значения будут играть роль индекса в новом листе.

# %%
commits.groupby("name")  # разложим все вклады по именам вкладчиков

# %% [markdown]
# Объект со сгруппированными по указанному столбцу объектами мы и видим, но, чтобы его использовать по назначению, требуется агрегировать случаи в каждой группе:

# %%
commits.groupby("name").sum()  # количество овощей, *сгруппированное* по имени вкладчика:
# Out:
#       potatoes  carrots
# name
# Вася        10       17
# Петя        13        5
# Таня         0       15

# %% [markdown]
# Чтобы вычислить несколько статистических функций, можно использовать метод `agg` (синоним `aggregate`).

# %%
commits.groupby("name").carrots.aggregate(["min", "max"])  # мин. и макс. количество морковок за один вклад
# Out:
#       min  max
# name
# Вася    2   15
# Петя    0    2
# Таня    4    6

# %% [markdown]
# Если агрегацию при этом сделать сразу по нескольким числовым столбцам, то у нас получится *двухуровневый индекс* для столбцов:

# %%
pt = commits.groupby("name").aggregate(["min", "max"])  # мин. и макс. количество овощей за один вклад
pt
# Out:
#      potatoes     carrots
#           min max     min max
# name
# Вася        4   6       2  15
# Петя        3   4       0   2
# Таня        0   0       4   6

# %% [markdown]
# ### Сводная таблица `pivot_table`

# %% [markdown]
# Иногда нужно осуществить группировку случаев-строк сразу **по нескольким категориальным параметрам**.
#
# Допустим, участники олимпиады по программированию отправляли задачи в электронный контест. Таблица отправок в систему содержит:
#
# 1. `run_id` — идентификатор запуска проверки,
# 2. `username` — хеш имени пользователя,
# 3. `problem` — букву-идентификатор решаемой задачи,
# 4. `result` — вердикт проверяющей системы,
# 5. `tests` — количество успешно пройденных тестов при запуске,
# 6. `score` — набранные очки.

# %%
runs = pd.read_csv("olymp3_results.csv", index_col='run_id')
runs.head(10)
# Out:
#         username problem   result  tests  score
# run_id
# 0       ae7ba9eb       B       OK     12    120
# 1       3470f1fd       A       OK      4    100
# 2       ae7ba9eb       C       OK     20    120
# 3       3470f1fd       B  partial     11     11
# 4       3470f1fd       B       OK     12    119
# 5       ae7ba9eb       D  partial     49     49
# 6       ae7ba9eb       D       OK     50     99
# 7       3470f1fd       D       OK     50    100
# 8       6bfd137c       A       OK      4    100
# 9       ae7ba9eb       E  partial      4      4

# %% [markdown]
# Обратите внимание, что один и тот же участник мог отправлять задачу много раз.
# Допустим, нас интересует максимальное количество очков за каждый вид задачи, причём отдельно для каждого пользователя.
#
# В этом случае разумно сделать в сводной таблице идентификатор пользователя индексом-меткой строки, а букву-идентификатор задачи — индексом-меткой столбца. При этом информация из столбцов `result`, `test` и индекса `run_id` нас не интересует совсем: в качестве *значений* нас интересует только `score`:

# %%
standings = runs.pivot_table(values="score",
                             index="username",
                             columns="problem",
                             aggfunc="max")
standings  # сводная таблица результатов участников
# Out:
# problem       A      B      C      D      E      F      G
# username
# 012ebf1a  100.0  119.0  120.0  100.0    NaN    NaN    NaN
# 04652344  100.0  120.0  120.0   99.0    NaN  200.0  200.0
# 133bea0b   99.0  119.0  115.0   99.0  149.0  197.0  198.0
# 144a02e6   99.0  119.0    3.0   99.0  150.0    NaN    2.0
# 3274f498  100.0  119.0  119.0   99.0  149.0    NaN  197.0
# 3470f1fd  100.0  119.0  120.0  100.0  149.0  197.0  194.0
# 4d990bd5    NaN    NaN  120.0    NaN    NaN    NaN    NaN
# 63590cda    NaN    NaN    0.0    NaN    NaN    NaN    NaN
# 6bfd137c  100.0  120.0   19.0  100.0    NaN    NaN    NaN
# 88d40a26  100.0  120.0  120.0  100.0  150.0    NaN  200.0
# 898693b2  100.0  120.0  120.0   99.0  144.0  198.0  194.0
# 98920ce6   98.0  120.0  115.0  100.0    NaN    NaN    NaN
# 9bffce24  100.0  120.0  120.0  100.0  149.0    NaN  197.0
# ae7ba9eb    NaN  120.0  120.0   99.0  148.0  199.0  193.0
# b5f8b678  100.0  120.0  112.0  100.0  149.0    NaN  199.0
# baee5b3d  100.0  119.0  120.0   99.0  148.0  197.0  194.0
# bf376a59  100.0  120.0  119.0   99.0    3.0  200.0  200.0
# bfd5e77e  100.0  120.0  120.0  100.0  150.0    NaN    NaN
# c0065bd3   98.0  120.0    NaN   49.0  150.0    NaN    NaN
# cbd1e30b   99.0  120.0  120.0   99.0    NaN  200.0  190.0
# cdd8d075  100.0  119.0  120.0   98.0  150.0  200.0    NaN
# d4b7e0db  100.0    NaN    NaN    NaN    NaN    NaN    NaN
# f5df05d6   97.0  118.0  113.0  100.0    NaN    NaN    NaN
# f832dae3   98.0  120.0  120.0   99.0  148.0  200.0  199.0

# %% [markdown]
# Из пожеланий к этой таблице результатов:

# %%
# 1. Заменить `NaN` на 0.
standings.fillna(0, inplace=True)  # можно было указать fill_value=0 для pivot_table
standings.head(3)
# Out:
# problem       A      B      C      D      E      F      G
# username
# 012ebf1a  100.0  119.0  120.0  100.0    0.0    0.0    0.0
# 04652344  100.0  120.0  120.0   99.0    0.0  200.0  200.0
# 133bea0b   99.0  119.0  115.0   99.0  149.0  197.0  198.0

# %%
# 2. В последнем столбце `score` посчитать сумму
#    максимальных достигнутых баллов для каждого пользователя.
standings["score"] = standings.sum(axis=1)
standings.head(3)
# Out:
# problem       A      B      C      D      E      F      G  score
# username
# 012ebf1a  100.0  119.0  120.0  100.0    0.0    0.0    0.0  439.0
# 04652344  100.0  120.0  120.0   99.0    0.0  200.0  200.0  839.0
# 133bea0b   99.0  119.0  115.0   99.0  149.0  197.0  198.0  976.0

# %%
# 3. Отсортировать по убыванию `score` все строки таблицы.
standings.sort_values(by="score", ascending=False, inplace=True)
standings.head(3)  # лучшие по сумме баллов 3 участника олимпиады:
# Out:
# problem       A      B      C      D      E      F      G  score
# username
# f832dae3   98.0  120.0  120.0   99.0  148.0  200.0  199.0  984.0
# 3470f1fd  100.0  119.0  120.0  100.0  149.0  197.0  194.0  979.0
# baee5b3d  100.0  119.0  120.0   99.0  148.0  197.0  194.0  977.0

# %% [markdown]
# ### Разворачивание сводной таблицы `melt`

# %% [markdown]
# **Обратное преобразование из сводной таблицы в таблицу случаев невозможно!**
#
# Это очевидно, поскольку:
# 1. при подготовке сводной таблицы производилась агрегация (редукция серии чисел к одному числу),
# 2. часть столбцов, не относящаяся к `values`, игнорировалась.
#
# Однако можно развернуть ту небольшую статистическую выжимку, которая у нас осталась.
# Для таблицы результатов олимпиады это будут только лучшие отправки по каждому пользователю и задаче:

# %%
standings.reset_index().melt(id_vars=['username'],
                             value_vars=['A', 'B', 'C', 'C', 'E', 'F', 'G'])
# Out:
#      username problem  value
# 0    f832dae3       A   98.0
# 1    3470f1fd       A  100.0
# 2    baee5b3d       A  100.0
# 3    133bea0b       A   99.0
# 4    898693b2       A  100.0
# ..        ...     ...    ...
# 139  c0065bd3       G    0.0
# 140  6bfd137c       G    0.0
# 141  4d990bd5       G    0.0
# 142  d4b7e0db       G    0.0
# 143  63590cda       G    0.0
#
# [144 rows x 3 columns]

# %% [markdown]
# Замечание. Для того, чтобы использовать `username` в качестве `id_vars`, пришлось вначале убрать его из индекса в обычный столбец при помощи `reset_index()`.

# %% [markdown]
# ## Слияние данных из нескольких таблиц

# %% [markdown]
# Иногда данные о случаях или объектах содержатся в нескольких таблицах, при этом в каждой таблице есть своя специфика.

# %% [markdown]
# ### Конкатенация таблиц `concat`

# %% [markdown]
# При использовании конкатенации происходит **механическое прибавление строк** второй таблицы к строкам первой таблицы:

# %%
scores1 = pd.DataFrame({'login':  ['login1', 'login2', 'login3'],
                        'A': [2, 0, 5], 'B': [5, 3, 5], 'C': [5, 3, 5],})
scores1
# Out:
#     login  A  B  C
# 0  login1  2  5  5
# 1  login2  0  3  3
# 2  login3  5  5  5

# %%
scores2 = pd.DataFrame({'login':  ['login4', 'login5'],
                        'A': [1, 3], 'B': [3, 0], 'C': [4, 2]})
scores2
# Out:
#     login  A  B  C
# 0  login4  1  3  4
# 1  login5  3  0  2

# %%
scores = pd.concat([scores1, scores2])
scores
# Out:
#     login  A  B  C
# 0  login1  2  5  5
# 1  login2  0  3  3
# 2  login3  5  5  5
# 0  login4  1  3  4
# 1  login5  3  0  2

# %%
# можно было при pd.concat() добавить ignore_index=True,
# но можно и починить поломанный индекс вручную (методом его отбрасывания):
scores.reset_index(inplace=True)
scores.drop(columns=["index"], inplace=True)
scores
# Out:
#     login  A  B  C
# 0  login1  2  5  5
# 1  login2  0  3  3
# 2  login3  5  5  5
# 3  login4  1  3  4
# 4  login5  3  0  2

# %% [markdown]
# Возможна и **конкатенация по горизонтали**  с указанием `axis=1`:

# %%
scores3 = pd.DataFrame({'login':  ['login2', 'login5', 'login6'],
                        'D': [8, 2, 7], 'E': [3, 0, 10]})
scores3
# Out:
#     login  D   E
# 0  login2  8   3
# 1  login5  2   0
# 2  login6  7  10

# %%
pd.concat([scores, scores3], axis=1)
# Out:
#     login  A  B  C   login    D     E
# 0  login1  2  5  5  login2  8.0   3.0
# 1  login2  0  3  3  login5  2.0   0.0
# 2  login3  5  5  5  login6  7.0  10.0
# 3  login4  1  3  4     NaN  NaN   NaN
# 4  login5  3  0  2     NaN  NaN   NaN

# %% [markdown]
# Внимание!!! Теперь **сломана сама логика объединения**, так как при соединении нужно учитывать равенство `login`.
#
# Так делать не стоит!

# %% [markdown]
# ### Объединение таблиц при помощи `merge`

# %% [markdown]
# Для объединения таблиц используем метод `merge`:

# %%
scores.merge(scores3)
# Out:
#     login  A  B  C  D  E
# 0  login2  0  3  3  8  3
# 1  login5  3  0  2  2  0

# %% [markdown]
# У нас правильно соединились данные! Но есть нюанс в том, *как* это произошло.
#
# **Стратегия объединения** указывается в параметре `how`.
#
# Мы не указали в `merge()` никаких значений параметров, а параметр `how` по умолчанию равен `'inner'`. Эта стратегия — взять только те строки, где есть полнота данных и слева, и справа. За ключи объединения берутся столбцы с одинаковыми названиями в обеих таблицах (у нас это `login`).
#
# Вот и получается, что при `how='inner'` *в пересечении множеств ключей* (по значениями столбца `login`) оказывается только два ключа: `login2` и `login5`.
#
# Есть ещё 4 стратегии объединения:

# %%
# `left`: сохранить всё из левой таблицы,
# информация из правой -- при совпадении ключей
scores.merge(scores3, how='left')
# Out:
#     login  A  B  C    D    E
# 0  login1  2  5  5  NaN  NaN
# 1  login2  0  3  3  8.0  3.0
# 2  login3  5  5  5  NaN  NaN
# 3  login4  1  3  4  NaN  NaN
# 4  login5  3  0  2  2.0  0.0

# %%
# `right`: сохранить всё из правой таблицы,
# информация из левой -- при совпадении ключей
scores.merge(scores3, how='right')
# Out:
#     login    A    B    C  D   E
# 0  login2  0.0  3.0  3.0  8   3
# 1  login5  3.0  0.0  2.0  2   0
# 2  login6  NaN  NaN  NaN  7  10

# %%
#`outer`: использует объединение ключей из обеих таблиц,
# сохранены все ключи и вся информация из обеих таблиц,
# зато пустые ячейки теперь есть во всех столбцах...
scores.merge(scores3, how='outer')
# Out:
#     login    A    B    C    D     E
# 0  login1  2.0  5.0  5.0  NaN   NaN
# 1  login2  0.0  3.0  3.0  8.0   3.0
# 2  login3  5.0  5.0  5.0  NaN   NaN
# 3  login4  1.0  3.0  4.0  NaN   NaN
# 4  login5  3.0  0.0  2.0  2.0   0.0
# 5  login6  NaN  NaN  NaN  7.0  10.0

# %% [markdown]
# Стратегия слияния `how='cross'` создает *декартово произведение* данных из обеих таблиц.
# Для таблиц выше это не имеет смысла, поэтому приведём другой пример.
#
# Есть юноши и девушки, для которых мы хотим вычислить степень их сходства:

# %%
boys = pd.DataFrame({'name':  ['Петр', 'Василий', 'Тихон'],
                     'height': [183, 157, 172], 'weight': [78, 65, 95]})
boys
# Out:
#       name  height  weight
# 0     Петр     183      78
# 1  Василий     157      65
# 2    Тихон     172      95

# %%
girls = pd.DataFrame({'name':  ['Мария', 'Наталья', 'Ирина'],
                      'height': [173, 164, 154], 'weight': [81, 62, 52]})
girls
# Out:
#       name  height  weight
# 0    Мария     173      81
# 1  Наталья     164      62
# 2    Ирина     154      52

# %%
pairs = boys.merge(girls, how='cross')
pairs
# Out:
#     name_x  height_x  weight_x   name_y  height_y  weight_y
# 0     Петр       183        78    Мария       173        81
# 1     Петр       183        78  Наталья       164        62
# 2     Петр       183        78    Ирина       154        52
# 3  Василий       157        65    Мария       173        81
# 4  Василий       157        65  Наталья       164        62
# 5  Василий       157        65    Ирина       154        52
# 6    Тихон       172        95    Мария       173        81
# 7    Тихон       172        95  Наталья       164        62
# 8    Тихон       172        95    Ирина       154        52

# %% [markdown]
# Допустим, мы считаем пару подходящей, если юноша выше девушки, но не более, чем на 20 сантиметров, а её вес меньше его хотя бы на 5 кг:

# %%
pairs["match"] = (abs(pairs.height_x - pairs.height_y - 10) <= 10) & (pairs.weight_x >= pairs.weight_y + 5)
pairs
# Out:
#     name_x  height_x  weight_x   name_y  height_y  weight_y  match
# 0     Петр       183        78    Мария       173        81  False
# 1     Петр       183        78  Наталья       164        62   True
# 2     Петр       183        78    Ирина       154        52  False
# 3  Василий       157        65    Мария       173        81  False
# 4  Василий       157        65  Наталья       164        62  False
# 5  Василий       157        65    Ирина       154        52   True
# 6    Тихон       172        95    Мария       173        81  False
# 7    Тихон       172        95  Наталья       164        62   True
# 8    Тихон       172        95    Ирина       154        52   True

# %% [markdown]
# Осталось взять из таблицы только подходящие пары, а затем выбросить и сам столбец `match`:

# %%
# в квадратных скобках можно использовать логическую серию
matched = pairs[pairs.match].drop(columns=['match'])
matched
# Out:
#     name_x  height_x  weight_x   name_y  height_y  weight_y
# 1     Петр       183        78  Наталья       164        62
# 5  Василий       157        65    Ирина       154        52
# 7    Тихон       172        95  Наталья       164        62
# 8    Тихон       172        95    Ирина       154        52

# %% [markdown]
# Теперь ясно, кого с кем нужно пробовать поженить :-)

# %% [markdown]
# ### Объединение таблиц при помощи `join`

# %% [markdown]
# Метод `join` очень похож на `merge`, но отличается поведением по умолчанию:
# 1. при отсутствии ключевого параметра `on=` для объединения **используются индексы**,
# 2. при отсутствии ключевого параметра `how=` выбирается стратегия `'left'`.

# %%
boys.join(girls, lsuffix='_of_boy', rsuffix='_of_girl')
# Out:
#   name_of_boy  height_of_boy  weight_of_boy name_of_girl  height_of_girl  \
# 0        Петр            183             78        Мария             173
# 1     Василий            157             65      Наталья             164
# 2       Тихон            172             95        Ирина             154
#
#    weight_of_girl
# 0              81
# 1              62
# 2              52

# %% [markdown]
# Если вы сталкивались с реляционными базами данных, то упомянутые стратегии `merge` напоминают вам стратегии `JOIN` в SQL.
#
# Листы с данными типа `DataFrame` имеют сходство с таблицами реляционных SQL баз данных, хотя есть и отличия:
#
# | SQL таблица               | Pandas DataFrame                                        |
# | :------------------------ | :------------------------------------------------------ |
# | столбцы с именами         | столбцы с индексами-метками                             |
# | столбцы со строгим типом  | столбцы типизированные (почти всегда)                   |
# | порядок строк не задан    | порядок строк определён, можно сорировать               |
# | доступ к строке по ключу  | доступ к строке по индексу-метке или числовому индексу  |
# | первичный ключ уникален   | индекс-метка может быть не уникальна                    |
